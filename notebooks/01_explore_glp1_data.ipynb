# %%
import pandas as pd

# Load the Excel file
xls_path = "../data/raw/GLP1R_complete_approx.xlsx"   # IMPORTANT: adjust path if notebook is elsewhere
xls = pd.ExcelFile(xls_path)

# Show all sheet names
xls.sheet_names
# Out:
# ['Candidate_Profiling',
#  'Fig3_DialIn_Approx',
#  'Fig4_DMS_Approx',
#  'Fig5_Glu_HLE_Approx',
#  'Fig6_FineTune_Approx',
#  'Fig7_Mouse_BW_Curve',
#  'Fig7_Mouse_Endpoints',
#  'GLP1 Model Performance (Figure ']

# %%
df_fig3  = pd.read_excel(xls, "Fig3_DialIn_Approx")
df_fig4  = pd.read_excel(xls, "Fig4_DMS_Approx")
df_fig5  = pd.read_excel(xls, "Fig5_Glu_HLE_Approx")
df_fig6  = pd.read_excel(xls, "Fig6_FineTune_Approx")
df_bw    = pd.read_excel(xls, "Fig7_Mouse_BW_Curve")
df_end   = pd.read_excel(xls, "Fig7_Mouse_Endpoints")
df_cand  = pd.read_excel(xls, "Candidate_Profiling")

df_fig3.head(), df_fig4.head(), df_fig5.head(), df_fig6.head(), df_bw.head(), df_end.head(), df_cand.head()
# Out:
# (   Position Substitution     Endpoint  Approx_Value
#  0         2          Aib  hGLP1R_EC50           1.5
#  1         2          Aib   hSCTR_EC50          -0.5
#  2         3            E  hGLP1R_EC50           0.5
#  3         9            D  hGLP1R_EC50           2.0
#  4         9            D   hSCTR_EC50          -1.0,
#     Position Substitution      Endpoint  Approx_Value
#  0         9            D  hGLP1R_pEC50           8.5
#  1         9            D   hSCTR_pEC50           6.5
#  2        12            Y  hGLP1R_pEC50           8.7
#  3        12            Y   hSCTR_pEC50           6.2
#  4        25            H  hGLP1R_pEC50           8.4,
#     Position Substitution     Endpoint  Approx_Value
#  0        12        Y+HLE  hGLP1R_EC50           2.0
#  1        12        Y+HLE   hSCTR_EC50          -1.5
#  2        14        F+HLE  hGLP1R_EC50           1.8
#  3        14        F+HLE   hSCTR_EC50          -1.0
#  4        16          L+E  hGLP1R_EC50           1.5,
# ...
